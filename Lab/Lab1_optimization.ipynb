# %%
def choose_and_use_function(case, x):
  if not case in [1, 2, 3]: 
  st.error('Error! You need to choose case 1 or 2, or 3')
  
    def f1(x):\n', 
  ' if len(x) != 2:\n', 
  " st.error('Error: You need to use a 2D x (a list with 2 elements)')\n", 
  ' return\n', ' x1, x2 = x[0], x[1]\n', 
  ' return (x1-1)**2 + 0.01 * (x2 - 1.33)**2\n', '\n', 
  
  
  ' def f2(x):\n', 
  ' if len(x) != 2:\n', 
  " st.error('Error: You need to use a 2D x (a list with 2 elements)')\n", 
  ' return\n', ' x1, x2 = x[0], x[1]\n', 
  ' return x1**4 - 16 * x1**2 + 5 * x1 + x2**4 - 16 * x2**2 + 5 * x2\n', '\n', 
  '\n', 

  ' def f3(x):\n', 
  ' if len(x) != 3:\n', 
  " st.error('Error: You need to use a 3D x (a list with 3 elements)')\n", 
  ' return\n', ' from math import cos, pi\n', 
  ' a = [0.1, -0.35, 0.95]\n', ' f_val = 30\n', 
  ' for i in range(len(x)):\n', 
  ' f_val += (x[i]-a[i])**2 - 10*cos(2*pi*(x[i] - a[i]))\n', 
  ' return f_val\n', '\n', 

' if case == 1:\n', 
' return f1(x)\n', 

' elif case == 2:\n', 
' return f2(x)\n', 

' elif case == 3:\n', 
' return f3(x)\n'], 2)

# %%
opt_fn_1 = []
opt_fn_2 = []
for i in range(5):
  for j in range(5):
    f1 = choose_and_use_function(1, [i, j])
    f2 = choose_and_use_function(2, [i, j])
    opt_fn_1.append(f1)
    opt_fn_2.append(f2)
print(opt_fn_1)
print(opt_fn_2)
